# %% [markdown]
# <a href="https://colab.research.google.com/github/hechen2020/19ma573HuixinChen/blob/master/src/btcs_stability_heat_1d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# other parameters
al = 1
dx = .2 #space mesh size
rho = 1. #conditinal number, to be less than .5 for the stability
dt = rho*(dx**2)/al #time step size

# %%
# initial function f
def init_f(x):
  return np.sin(np.pi*x)

# %%
# true function
def true_f(x,t):
  return np.exp(-np.pi**2 * t)*np.sin(np.pi * x)

# %% [markdown]
# **Use ftcs to solve heat equation and find subnorm of error function**

# %%
def ftcs(a,b,nt,dx,dt,rho):
  nx = int((b-a)/dx)
  u = np.zeros((nt,nx))
  
  for x in range(0,nx):
    u[0][x] = init_f(a+x*dx)
    
  for t in range(0,nt-1):
    for x in range(1,nx-1):
      u[t+1][x] = rho*(u[t][x-1]) + (1-2*rho)*(u[t][x]) + rho*(u[t][x+1])
      
      
  return u

# %%
ftcs_sol = ftcs(0,1,200,dx,dt,rho)
#print(ftcs_sol)

# %%
def error_fcn(a,b,nt,dx,dt,sol):
  nx = int((b-a)/dx)
  e = np.zeros((nt,nx))
  
  for t in range(nt):
    for x in range(nx):
      e[t][x] = np.abs(sol[t][x]-true_f(a+x*dx,t*dt))
  return e

# %%
err = error_fcn(0, 1, 200, dx, dt, ftcs_sol)
superr = np.max(err)
print('the supnorm of error function is ' + str(superr))
#print(err)
# Out:
# the supnorm of error function is 2.609198345490077e+74

# %% [markdown]
# Since the supnorm of the ftcs sol is sufficiently large, we can say the ftcs method diverge and supnorm is $\infty$

# %%
xx = np.arange(0,1,.2)
print(xx)
error1 = np.zeros(5)
for i in range(len(error1)):
  error1[i] = true_f(xx[i], 1.92) - ftcs_sol[int(1.92/dt)][i]
print(error1)
error2 = np.zeros(5)
for i in range(len(error2)):
  error2[i] = true_f(xx[i], 1.96) - ftcs_sol[int(1.96/dt)][i]
print(error2)
error3 = np.zeros(5)
for i in range(len(error3)):
  error3[i] = true_f(xx[i], 2.00) - ftcs_sol[int(2.00/dt)][i]
print(error3)
plt.plot(xx,error1)
plt.plot(xx,error2)
plt.plot(xx,error3)
# Out:
# [0.  0.2 0.4 0.6 0.8]
# [ 0.00000000e+00 -1.21363453e+16  1.71633842e+16 -1.21363453e+16
#   3.46333422e-09]
# [ 0.00000000e+00  2.92997295e+16 -4.14360748e+16  2.92997295e+16
#   2.33368274e-09]
# [ 0.00000000e+00 -7.07358043e+16  1.00035534e+17 -7.07358043e+16
#   1.57249483e-09]

# %% [markdown]
# **Use btcs to solve heat equation and find subnorm of error function**

# %% [markdown]
# BTCS can be expressed as
#
# $$
# \begin{bmatrix}
#    1+2\rho & -\rho & 0 & \dots  & 0 \\
#     -\rho & \ddots & \ddots & \ddots  & \vdots \\
#     0 & \ddots & \ddots & \ddots & 0 \\
#     \vdots & \ddots & \ddots& \ddots & -\rho\\
#     0 & \dots & 0 & -\rho  & 1+2\rho
# \end{bmatrix}
# \times
# \begin{bmatrix}
#    u_{0,k+1} \\
#    u_{1,k+1} \\
#    \vdots \\
#    \vdots\\
#    u_{n,k+1}
# \end{bmatrix}
# =
# \begin{bmatrix}
#    u_{0,k} \\
#    u_{1,k} \\
#    \vdots \\
#    \vdots\\
#    u_{n,k}
# \end{bmatrix}
# $$
#
# so the upper level is the inverse of the matrix times the lower level

# %%
def btcs(a, b, nt, dx, dt, rho):
  nx = int((b-a)/dx)
  u = np.zeros((nt,nx))
  
  ld = np.repeat(-rho,nx-1)#lower diag
  md = np.repeat(1+2*rho,nx)#main diag
  ud = np.repeat(-rho,nx-1)#upper diag
  
  A = np.diag(ld, -1) + np.diag(md, 0) + np.diag(ud, 1)#matrix
  
  for x in range(0,nx):
    u[0][x] = init_f(a+x*dx)
  
  for t in range(0,nt-1):
    u[t+1][:] = np.linalg.inv(A).dot(u[t][:])
  
  return u

# %%
btcs_sol = btcs(0,1,200,dx,dt,rho)
#print(btcs_sol)

# %%
err = error_fcn(0, 1, 200, dx, dt, btcs_sol)
superr = np.max(err)
print('the supnorm of error function is ' + str(superr))
#print(err)
# Out:
# the supnorm of error function is 0.19016094194762306

# %% [markdown]
# **Plot three error curves with $t = 1.94, 1.96, 1.98$ for btcs**

# %%
xx = np.arange(0,1,.2)
print(xx)
error1 = np.zeros(5)
for i in range(len(error1)):
  error1[i] = true_f(xx[i], 1.92) - btcs_sol[int(1.92/dt)][i]
print(error1)
error2 = np.zeros(5)
for i in range(len(error2)):
  error2[i] = true_f(xx[i], 1.96) - btcs_sol[int(1.96/dt)][i]
print(error2)
error3 = np.zeros(5)
for i in range(len(error3)):
  error3[i] = true_f(xx[i], 2.00) - btcs_sol[int(2.00/dt)][i]
print(error3)
plt.plot(xx,error1)
plt.plot(xx,error2)
plt.plot(xx,error3)
# Out:
# [0.  0.2 0.4 0.6 0.8]
# [-6.12747436e-06 -1.06096336e-05 -1.22493449e-05 -1.06074931e-05
#  -6.12401103e-06]
# [-4.83258666e-06 -8.36795195e-06 -9.66139735e-06 -8.36650966e-06
#  -4.83025298e-06]
# [-3.81134094e-06 -6.59986366e-06 -7.62013753e-06 -6.59889180e-06
#  -3.80976844e-06]
